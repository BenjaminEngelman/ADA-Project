# %% [markdown]
# # Statistical Analysis for Demographics
#
# This notebook focuses on the statistical analysis for the results obtained in the Demographic Analysis section of main notebook.
# The main goal is to statistically measure the difference between socio-economics characteristics in terms of given situtation.
# An ANOVA test for equality of means is performed and deeper analysis is made with confidence intervals for the difference between two means.

# %% [markdown]
# ## Environment Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import plotly.express as px
import scipy.stats
from statsmodels.formula.api import ols

default_figsize = (12.8, 4.8)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Household Demographic

# %%
# Household demographics
df_household = pd.read_csv('dunnhumby/hh_demographic.csv', sep = ',')

# %% [markdown]
# #### Data Cleaning

# %%
# correct dtypes
df_household['MARITAL_STATUS_CODE'] = df_household['MARITAL_STATUS_CODE'].astype('category')
df_household['HOMEOWNER_DESC'] =  df_household['HOMEOWNER_DESC'].astype('category')
df_household['HH_COMP_DESC'] = df_household['HH_COMP_DESC'].astype('category')
df_household['HOUSEHOLD_SIZE_DESC'] = pd.Categorical(df_household['HOUSEHOLD_SIZE_DESC'].values, categories=['1', '2', '3', '4', '5+'], ordered=True)
df_household['KID_CATEGORY_DESC'] = pd.Categorical(df_household['KID_CATEGORY_DESC'].values, categories=['None/Unknown', '1', '2', '3+'], ordered=True)

# merge some income categories
cat_to_combine_under50K = ["Under 15K", "15-24K", "25-34K", "35-49K"]
cat_to_combine_between50K_100K = ["50-74K", "75-99K"]
cat_to_combine_over100K = ["100-124K", "125-149K", "150-174K", "175-199K", "200-249K", "250K+"]
def combine_cat_income(x):
    if x in cat_to_combine_over100K:
        return "100K+"
    elif x in cat_to_combine_between50K_100K:
        return "50-99K"
    elif x in cat_to_combine_under50K:
        return "Under 50K"
    else:
        print(x)
        return 'ERROR'
    
df_household['INCOME_DESC'] = df_household['INCOME_DESC'].apply(combine_cat_income)

# merge some age categories
cat_to_combine_over55 = ["55-64", "65+"]
cat_to_combine_under35 = ["19-24", "25-34"]
def combine_cat_age(x):
    if x in cat_to_combine_over55:
        return "55+" 
    elif x in cat_to_combine_under35:
        return "19-34"
    else: 
        return x
    
df_household['AGE_DESC'] = df_household['AGE_DESC'].apply(combine_cat_age)


# correct dtypes
df_household['INCOME_DESC'] = pd.Categorical(df_household['INCOME_DESC'].values, categories=['Under 50K', '50-99K', '100K+'], ordered=True)
df_household['AGE_DESC'] = pd.Categorical(df_household['AGE_DESC'].values, categories=['19-34', '35-44', '45-54', '55+'], ordered=True)

# %% [markdown]
# ### Products

# %%
df_products = pd.read_csv('dunnhumby/product.csv', sep = ',')
df_food_products = pd.read_csv('data/food_products.csv')

df_meat_products = pd.read_csv('data/meat_products.csv')
df_veggies_products = pd.read_csv('data/vegetables_products.csv')

df_pure_meat = pd.read_csv("data/pure_meat_products.csv")
df_red_meat = df_pure_meat[df_pure_meat.MEAT_TYPE.isin(['BOVINE', 'OVINE','PORK'])]
df_white_meat = df_pure_meat[df_pure_meat.MEAT_TYPE.isin(['POULTRY'])]
df_sea_food = df_pure_meat[df_pure_meat.MEAT_TYPE.isin(['SEAFOOD'])]

# %% [markdown]
# ### Transactions

# %%
df_transactions = pd.read_csv("data/clean_transactions.csv")
df_food_transactions = pd.read_csv("data/food_transactions.csv")

df_meat_transactions = pd.merge(df_meat_products, df_food_transactions, on="PRODUCT_ID", how="inner")
df_veggies_transactions = pd.merge(df_veggies_products, df_food_transactions, on="PRODUCT_ID", how="inner")

df_pure_meat_transactions = pd.merge(df_pure_meat, df_food_transactions, on="PRODUCT_ID", how="inner")
df_red_meat_transactions = pd.merge(df_red_meat, df_food_transactions, on="PRODUCT_ID", how="inner")
df_white_meat_transactions = pd.merge(df_white_meat, df_food_transactions, on="PRODUCT_ID", how="inner")
df_sea_food_transactions = pd.merge(df_sea_food, df_food_transactions, on="PRODUCT_ID", how="inner")

# %% [markdown]
# ### Aggregated Dataset

# %%
# find active weeks  and total spendings per household
weeks_activity_by_household = df_food_transactions.groupby("household_key").agg({"WEEK_NO": set, "PAID_PRICE": sum})
# create new columns
weeks_activity_by_household["number_of_active_weeks"] = weeks_activity_by_household["WEEK_NO"].apply(lambda x: len(x))
weeks_activity_by_household["avg_spending_per_week"] = weeks_activity_by_household["PAID_PRICE"] / weeks_activity_by_household["number_of_active_weeks"]
# drop week_no and sort
weeks_activity_by_household = weeks_activity_by_household.drop(columns="WEEK_NO")
weeks_activity_by_household = weeks_activity_by_household.sort_values(by="number_of_active_weeks", ascending=False).rename(columns={"PAID_PRICE": "PAID_FOOD"})

# %%
# find active weeks  and total spendings per household
weeks_activity_by_household = df_food_transactions.groupby("household_key").agg({"WEEK_NO": set, "PAID_PRICE": sum})
# create new columns
weeks_activity_by_household["number_of_active_weeks"] = weeks_activity_by_household["WEEK_NO"].apply(lambda x: len(x))
weeks_activity_by_household["avg_spending_per_week"] = weeks_activity_by_household["PAID_PRICE"] / weeks_activity_by_household["number_of_active_weeks"]
# drop week_no and sort
weeks_activity_by_household = weeks_activity_by_household.drop(columns="WEEK_NO")
weeks_activity_by_household = weeks_activity_by_household.sort_values(by="number_of_active_weeks", ascending=False).rename(columns={"PAID_PRICE": "PAID_FOOD"})

# add more info 
dfs = [df_meat_transactions, df_veggies_transactions, df_pure_meat_transactions, df_red_meat_transactions, df_white_meat_transactions, df_sea_food_transactions]
df_names = ['MEAT', 'VEGGIE', 'PURE_MEAT', 'RED_MEAT', 'WHITE_MEAT', 'SEA_FOOD']

spent_by_household = weeks_activity_by_household.rename(columns={"PAID_PRICE_x": "paid_FOOD", "PAID_PRICE_y": "paid"})
for name, df in zip(df_names, dfs):
    spending = df.groupby("household_key").agg({"PAID_PRICE": sum}).reset_index().rename(columns={"PAID_PRICE": "PAID_" + name})
    spent_by_household = pd.merge(spending, spent_by_household, on="household_key")
    
    spent_by_household['avg_spending_per_week_' + name] = spent_by_household['PAID_' + name] / spent_by_household['number_of_active_weeks']
    spent_by_household['avg_spending_ratio_' + name] = spent_by_household['avg_spending_per_week_' + name] / spent_by_household['avg_spending_per_week']

# %% [markdown]
# ## Statistical Analysis for Demographical comparison
#
# The ANOVA tests are shown for all the plots in the Demographical Analysis section of the main notebook. Comments on the results can be found in that notebook.

# %%
df_spent_and_demog=pd.merge(df_household, spent_by_household, on='household_key', how='inner')

# %%
def stats_data(df, demographic_feature, order=None):
    COLS_OF_INTEREST = [
    "avg_spending_per_week",  
    "avg_spending_ratio_MEAT",
    "avg_spending_ratio_VEGGIE",
    "avg_spending_ratio_PURE_MEAT",
    "avg_spending_ratio_RED_MEAT", 
    "avg_spending_ratio_WHITE_MEAT",
    "avg_spending_ratio_SEA_FOOD",
    ]
    
    
    for i, col in enumerate(COLS_OF_INTEREST):    
        print(demographic_feature, col)
df_spent_and_demog.columns
# Out:
# Index(['AGE_DESC', 'MARITAL_STATUS_CODE', 'INCOME_DESC', 'HOMEOWNER_DESC',
#        'HH_COMP_DESC', 'HOUSEHOLD_SIZE_DESC', 'KID_CATEGORY_DESC',
#        'household_key', 'PAID_SEA_FOOD', 'PAID_WHITE_MEAT', 'PAID_RED_MEAT',
#        'PAID_PURE_MEAT', 'PAID_VEGGIE', 'PAID_MEAT', 'PAID_FOOD',
#        'number_of_active_weeks', 'avg_spending_per_week',
#        'avg_spending_per_week_MEAT', 'avg_spending_ratio_MEAT',
#        'avg_spending_per_week_VEGGIE', 'avg_spending_ratio_VEGGIE',
#        'avg_spending_per_week_PURE_MEAT', 'avg_spending_ratio_PURE_MEAT',
#        'avg_spending_per_week_RED_MEAT', 'avg_spending_ratio_RED_MEAT',
#        'avg_spending_per_week_WHITE_MEAT', 'avg_spending_ratio_WHITE_MEAT',
#        'avg_spending_per_week_SEA_FOOD', 'avg_spending_ratio_SEA_FOOD'],
#       dtype='object')

# %% [markdown]
# ### AGE_DESC

# %%
results = ols('avg_spending_per_week ~ C(AGE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_MEAT ~ C(AGE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_VEGGIE ~ C(AGE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_PURE_MEAT ~ C(AGE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_RED_MEAT ~ C(AGE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_WHITE_MEAT ~ C(AGE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_SEA_FOOD ~ C(AGE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     avg_spending_per_week   R-squared:                       0.021
# Model:                               OLS   Adj. R-squared:                  0.017
# Method:                    Least Squares   F-statistic:                     5.303
# Date:                   Sat, 14 Dec 2019   Prob (F-statistic):            0.00128
# Time:                           20:28:00   Log-Likelihood:                -3392.9
# No. Observations:                    734   AIC:                             6794.
# Df Residuals:                        730   BIC:                             6812.
# Df Model:                              3
# Covariance Type:               nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               47.0735      1.893     24.861      0.000      43.356      50.791
# C(AGE_DESC)[T.35-44]     5.3412      2.651      2.015      0.044       0.136      10.546
# C(AGE_DESC)[T.45-54]     1.0907      2.421      0.451      0.652      -3.662       5.843
# C(AGE_DESC)[T.55+]      -6.2577      2.951     -2.121      0.034     -12.051      -0.465
# ==============================================================================
# Omnibus:                      191.965   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              475.992
# Skew:                           1.353   Prob(JB):                    4.36e-104
# Kurtosis:                       5.870   Cond. No.                         5.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     avg_spending_ratio_MEAT   R-squared:                       0.002
# Model:                                 OLS   Adj. R-squared:                 -0.002
# Method:                      Least Squares   F-statistic:                    0.4201
# Date:                     Sat, 14 Dec 2019   Prob (F-statistic):              0.739
# Time:                             20:28:00   Log-Likelihood:                 820.00
# No. Observations:                      734   AIC:                            -1632.
# Df Residuals:                          730   BIC:                            -1614.
# Df Model:                                3
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.2283      0.006     37.501      0.000       0.216       0.240
# C(AGE_DESC)[T.35-44]     0.0095      0.009      1.117      0.264      -0.007       0.026
# C(AGE_DESC)[T.45-54]     0.0042      0.008      0.534      0.594      -0.011       0.019
# C(AGE_DESC)[T.55+]       0.0048      0.009      0.501      0.617      -0.014       0.023
# ==============================================================================
# Omnibus:                       43.626   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.899
# Skew:                           0.503   Prob(JB):                     9.84e-14
# Kurtosis:                       3.973   Cond. No.                         5.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     avg_spending_ratio_VEGGIE   R-squared:                       0.027
# Model:                                   OLS   Adj. R-squared:                  0.023
# Method:                        Least Squares   F-statistic:                     6.707
# Date:                       Sat, 14 Dec 2019   Prob (F-statistic):           0.000181
# Time:                               20:28:00   Log-Likelihood:                 1387.9
# No. Observations:                        734   AIC:                            -2768.
# Df Residuals:                            730   BIC:                            -2749.
# Df Model:                                  3
# Covariance Type:                   nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.0664      0.003     23.625      0.000       0.061       0.072
# C(AGE_DESC)[T.35-44]     0.0052      0.004      1.318      0.188      -0.003       0.013
# C(AGE_DESC)[T.45-54]     0.0100      0.004      2.796      0.005       0.003       0.017
# C(AGE_DESC)[T.55+]       0.0187      0.004      4.269      0.000       0.010       0.027
# ==============================================================================
# Omnibus:                      160.867   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              428.509
# Skew:                           1.106   Prob(JB):                     8.92e-94
# Kurtosis:                       6.019   Cond. No.                         5.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     avg_spending_ratio_PURE_MEAT   R-squared:                       0.005
# Model:                                      OLS   Adj. R-squared:                  0.001
# Method:                           Least Squares   F-statistic:                     1.328
# Date:                          Sat, 14 Dec 2019   Prob (F-statistic):              0.264
# Time:                                  20:28:00   Log-Likelihood:                 897.53
# No. Observations:                           734   AIC:                            -1787.
# Df Residuals:                               730   BIC:                            -1769.
# Df Model:                                     3
# Covariance Type:                      nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.1771      0.005     32.318      0.000       0.166       0.188
# C(AGE_DESC)[T.35-44]     0.0111      0.008      1.442      0.150      -0.004       0.026
# C(AGE_DESC)[T.45-54]     0.0110      0.007      1.566      0.118      -0.003       0.025
# C(AGE_DESC)[T.55+]       0.0153      0.009      1.797      0.073      -0.001       0.032
# ==============================================================================
# Omnibus:                       49.302   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.489
# Skew:                           0.618   Prob(JB):                     1.21e-13
# Kurtosis:                       3.646   Cond. No.                         5.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_RED_MEAT   R-squared:                       0.018
# Model:                                     OLS   Adj. R-squared:                  0.014
# Method:                          Least Squares   F-statistic:                     4.375
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):            0.00460
# Time:                                 20:28:00   Log-Likelihood:                 1078.4
# No. Observations:                          734   AIC:                            -2149.
# Df Residuals:                              730   BIC:                            -2130.
# Df Model:                                    3
# Covariance Type:                     nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.0894      0.004     20.868      0.000       0.081       0.098
# C(AGE_DESC)[T.35-44]     0.0145      0.006      2.420      0.016       0.003       0.026
# C(AGE_DESC)[T.45-54]     0.0169      0.005      3.084      0.002       0.006       0.028
# C(AGE_DESC)[T.55+]       0.0211      0.007      3.157      0.002       0.008       0.034
# ==============================================================================
# Omnibus:                       86.294   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              119.605
# Skew:                           0.865   Prob(JB):                     1.07e-26
# Kurtosis:                       3.956   Cond. No.                         5.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     avg_spending_ratio_WHITE_MEAT   R-squared:                       0.016
# Model:                                       OLS   Adj. R-squared:                  0.012
# Method:                            Least Squares   F-statistic:                     3.982
# Date:                           Sat, 14 Dec 2019   Prob (F-statistic):            0.00789
# Time:                                   20:28:00   Log-Likelihood:                 1629.5
# No. Observations:                            734   AIC:                            -3251.
# Df Residuals:                                730   BIC:                            -3233.
# Df Model:                                      3
# Covariance Type:                       nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.0476      0.002     23.553      0.000       0.044       0.052
# C(AGE_DESC)[T.35-44]    -0.0031      0.003     -1.112      0.267      -0.009       0.002
# C(AGE_DESC)[T.45-54]    -0.0072      0.003     -2.775      0.006      -0.012      -0.002
# C(AGE_DESC)[T.55+]      -0.0093      0.003     -2.948      0.003      -0.015      -0.003
# ==============================================================================
# Omnibus:                      169.303   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              361.647
# Skew:                           1.263   Prob(JB):                     2.95e-79
# Kurtosis:                       5.333   Cond. No.                         5.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_SEA_FOOD   R-squared:                       0.009
# Model:                                     OLS   Adj. R-squared:                  0.004
# Method:                          Least Squares   F-statistic:                     2.092
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):             0.0999
# Time:                                 20:28:00   Log-Likelihood:                 1855.5
# No. Observations:                          734   AIC:                            -3703.
# Df Residuals:                              730   BIC:                            -3685.
# Df Model:                                    3
# Covariance Type:                     nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.0172      0.001     11.552      0.000       0.014       0.020
# C(AGE_DESC)[T.35-44]    -0.0014      0.002     -0.653      0.514      -0.005       0.003
# C(AGE_DESC)[T.45-54]     0.0019      0.002      0.994      0.320      -0.002       0.006
# C(AGE_DESC)[T.55+]       0.0039      0.002      1.677      0.094      -0.001       0.008
# ==============================================================================
# Omnibus:                      459.042   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4689.636
# Skew:                           2.716   Prob(JB):                         0.00
# Kurtosis:                      14.128   Cond. No.                         5.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### INCOME_DESC

# %%
results = ols('avg_spending_per_week ~ C(INCOME_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_MEAT ~ C(INCOME_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_VEGGIE ~ C(INCOME_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_PURE_MEAT ~ C(INCOME_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_RED_MEAT ~ C(INCOME_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_WHITE_MEAT ~ C(INCOME_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_SEA_FOOD ~ C(INCOME_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     avg_spending_per_week   R-squared:                       0.099
# Model:                               OLS   Adj. R-squared:                  0.096
# Method:                    Least Squares   F-statistic:                     40.12
# Date:                   Sat, 14 Dec 2019   Prob (F-statistic):           2.93e-17
# Time:                           20:28:16   Log-Likelihood:                -3362.6
# No. Observations:                    734   AIC:                             6731.
# Df Residuals:                        731   BIC:                             6745.
# Df Model:                              2
# Covariance Type:               nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   41.8767      1.280     32.714      0.000      39.364      44.390
# C(INCOME_DESC)[T.50-99K]     5.8185      1.929      3.016      0.003       2.031       9.606
# C(INCOME_DESC)[T.100K+]     22.2952      2.489      8.958      0.000      17.409      27.182
# ==============================================================================
# Omnibus:                      160.565   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              345.797
# Skew:                           1.195   Prob(JB):                     8.15e-76
# Kurtosis:                       5.366   Cond. No.                         3.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     avg_spending_ratio_MEAT   R-squared:                       0.061
# Model:                                 OLS   Adj. R-squared:                  0.059
# Method:                      Least Squares   F-statistic:                     23.94
# Date:                     Sat, 14 Dec 2019   Prob (F-statistic):           8.52e-11
# Time:                             20:28:16   Log-Likelihood:                 842.64
# No. Observations:                      734   AIC:                            -1679.
# Df Residuals:                          731   BIC:                            -1665.
# Df Model:                                2
# Covariance Type:                 nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.2527      0.004     60.748      0.000       0.245       0.261
# C(INCOME_DESC)[T.50-99K]    -0.0308      0.006     -4.910      0.000      -0.043      -0.018
# C(INCOME_DESC)[T.100K+]     -0.0506      0.008     -6.258      0.000      -0.066      -0.035
# ==============================================================================
# Omnibus:                       46.054   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.245
# Skew:                           0.507   Prob(JB):                     4.12e-15
# Kurtosis:                       4.067   Cond. No.                         3.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     avg_spending_ratio_VEGGIE   R-squared:                       0.006
# Model:                                   OLS   Adj. R-squared:                  0.003
# Method:                        Least Squares   F-statistic:                     2.043
# Date:                       Sat, 14 Dec 2019   Prob (F-statistic):              0.130
# Time:                               20:28:16   Log-Likelihood:                 1380.0
# No. Observations:                        734   AIC:                            -2754.
# Df Residuals:                            731   BIC:                            -2740.
# Df Model:                                  2
# Covariance Type:                   nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.0722      0.002     36.083      0.000       0.068       0.076
# C(INCOME_DESC)[T.50-99K]     0.0022      0.003      0.727      0.468      -0.004       0.008
# C(INCOME_DESC)[T.100K+]      0.0079      0.004      2.021      0.044       0.000       0.015
# ==============================================================================
# Omnibus:                      156.788   Durbin-Watson:                   2.092
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              378.209
# Skew:                           1.118   Prob(JB):                     7.46e-83
# Kurtosis:                       5.715   Cond. No.                         3.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     avg_spending_ratio_PURE_MEAT   R-squared:                       0.036
# Model:                                      OLS   Adj. R-squared:                  0.034
# Method:                           Least Squares   F-statistic:                     13.76
# Date:                          Sat, 14 Dec 2019   Prob (F-statistic):           1.36e-06
# Time:                                  20:28:16   Log-Likelihood:                 909.09
# No. Observations:                           734   AIC:                            -1812.
# Df Residuals:                               731   BIC:                            -1798.
# Df Model:                                     2
# Covariance Type:                      nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.2004      0.004     52.747      0.000       0.193       0.208
# C(INCOME_DESC)[T.50-99K]    -0.0238      0.006     -4.156      0.000      -0.035      -0.013
# C(INCOME_DESC)[T.100K+]     -0.0327      0.007     -4.427      0.000      -0.047      -0.018
# ==============================================================================
# Omnibus:                       49.448   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.507
# Skew:                           0.622   Prob(JB):                     1.20e-13
# Kurtosis:                       3.632   Cond. No.                         3.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_RED_MEAT   R-squared:                       0.033
# Model:                                     OLS   Adj. R-squared:                  0.031
# Method:                          Least Squares   F-statistic:                     12.63
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):           4.07e-06
# Time:                                 20:28:16   Log-Likelihood:                 1084.3
# No. Observations:                          734   AIC:                            -2163.
# Df Residuals:                              731   BIC:                            -2149.
# Df Model:                                    2
# Covariance Type:                     nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.1119      0.003     37.403      0.000       0.106       0.118
# C(INCOME_DESC)[T.50-99K]    -0.0130      0.005     -2.884      0.004      -0.022      -0.004
# C(INCOME_DESC)[T.100K+]     -0.0282      0.006     -4.852      0.000      -0.040      -0.017
# ==============================================================================
# Omnibus:                       89.151   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.933
# Skew:                           0.883   Prob(JB):                     7.43e-28
# Kurtosis:                       3.984   Cond. No.                         3.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     avg_spending_ratio_WHITE_MEAT   R-squared:                       0.006
# Model:                                       OLS   Adj. R-squared:                  0.003
# Method:                            Least Squares   F-statistic:                     2.162
# Date:                           Sat, 14 Dec 2019   Prob (F-statistic):              0.116
# Time:                                   20:28:16   Log-Likelihood:                 1625.7
# No. Observations:                            734   AIC:                            -3245.
# Df Residuals:                                731   BIC:                            -3232.
# Df Model:                                      2
# Covariance Type:                       nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.0444      0.001     31.054      0.000       0.042       0.047
# C(INCOME_DESC)[T.50-99K]    -0.0044      0.002     -2.029      0.043      -0.009      -0.000
# C(INCOME_DESC)[T.100K+]     -0.0007      0.003     -0.266      0.791      -0.006       0.005
# ==============================================================================
# Omnibus:                      168.382   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              356.649
# Skew:                           1.261   Prob(JB):                     3.59e-78
# Kurtosis:                       5.303   Cond. No.                         3.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_SEA_FOOD   R-squared:                       0.018
# Model:                                     OLS   Adj. R-squared:                  0.015
# Method:                          Least Squares   F-statistic:                     6.565
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):            0.00149
# Time:                                 20:28:16   Log-Likelihood:                 1858.9
# No. Observations:                          734   AIC:                            -3712.
# Df Residuals:                              731   BIC:                            -3698.
# Df Model:                                    2
# Covariance Type:                     nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.0170      0.001     16.310      0.000       0.015       0.019
# C(INCOME_DESC)[T.50-99K]  9.858e-06      0.002      0.006      0.995      -0.003       0.003
# C(INCOME_DESC)[T.100K+]      0.0069      0.002      3.408      0.001       0.003       0.011
# ==============================================================================
# Omnibus:                      452.936   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4531.464
# Skew:                           2.676   Prob(JB):                         0.00
# Kurtosis:                      13.933   Cond. No.                         3.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### HOUSEHOLD_SIZE_DESC

# %%
results = ols('avg_spending_per_week ~ C(HOUSEHOLD_SIZE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_MEAT ~ C(HOUSEHOLD_SIZE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_VEGGIE ~ C(HOUSEHOLD_SIZE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_PURE_MEAT ~ C(HOUSEHOLD_SIZE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_RED_MEAT ~ C(HOUSEHOLD_SIZE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_WHITE_MEAT ~ C(HOUSEHOLD_SIZE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_SEA_FOOD ~ C(HOUSEHOLD_SIZE_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     avg_spending_per_week   R-squared:                       0.034
# Model:                               OLS   Adj. R-squared:                  0.029
# Method:                    Least Squares   F-statistic:                     6.477
# Date:                   Sat, 14 Dec 2019   Prob (F-statistic):           4.00e-05
# Time:                           20:28:44   Log-Likelihood:                -3388.0
# No. Observations:                    734   AIC:                             6786.
# Df Residuals:                        729   BIC:                             6809.
# Df Model:                              4
# Covariance Type:               nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       42.5420      1.611     26.405      0.000      39.379      45.705
# C(HOUSEHOLD_SIZE_DESC)[T.2]      4.8000      2.158      2.224      0.026       0.563       9.037
# C(HOUSEHOLD_SIZE_DESC)[T.3]      9.4601      2.925      3.234      0.001       3.717      15.203
# C(HOUSEHOLD_SIZE_DESC)[T.4]     12.3352      3.925      3.142      0.002       4.629      20.042
# C(HOUSEHOLD_SIZE_DESC)[T.5+]    14.2314      3.508      4.056      0.000       7.343      21.119
# ==============================================================================
# Omnibus:                      179.059   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              413.484
# Skew:                           1.295   Prob(JB):                     1.63e-90
# Kurtosis:                       5.610   Cond. No.                         5.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     avg_spending_ratio_MEAT   R-squared:                       0.006
# Model:                                 OLS   Adj. R-squared:                  0.000
# Method:                      Least Squares   F-statistic:                     1.020
# Date:                     Sat, 14 Dec 2019   Prob (F-statistic):              0.396
# Time:                             20:28:44   Log-Likelihood:                 821.41
# No. Observations:                      734   AIC:                            -1633.
# Df Residuals:                          729   BIC:                            -1610.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.2323      0.005     44.620      0.000       0.222       0.243
# C(HOUSEHOLD_SIZE_DESC)[T.2]      0.0016      0.007      0.236      0.813      -0.012       0.015
# C(HOUSEHOLD_SIZE_DESC)[T.3]      0.0113      0.009      1.195      0.232      -0.007       0.030
# C(HOUSEHOLD_SIZE_DESC)[T.4]     -0.0121      0.013     -0.954      0.340      -0.037       0.013
# C(HOUSEHOLD_SIZE_DESC)[T.5+]    -0.0093      0.011     -0.823      0.411      -0.032       0.013
# ==============================================================================
# Omnibus:                       39.339   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.442
# Skew:                           0.476   Prob(JB):                     4.10e-12
# Kurtosis:                       3.899   Cond. No.                         5.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     avg_spending_ratio_VEGGIE   R-squared:                       0.018
# Model:                                   OLS   Adj. R-squared:                  0.013
# Method:                        Least Squares   F-statistic:                     3.417
# Date:                       Sat, 14 Dec 2019   Prob (F-statistic):            0.00884
# Time:                               20:28:44   Log-Likelihood:                 1384.7
# No. Observations:                        734   AIC:                            -2759.
# Df Residuals:                            729   BIC:                            -2736.
# Df Model:                                  4
# Covariance Type:                   nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0732      0.002     30.296      0.000       0.068       0.078
# C(HOUSEHOLD_SIZE_DESC)[T.2]      0.0067      0.003      2.064      0.039       0.000       0.013
# C(HOUSEHOLD_SIZE_DESC)[T.3]     -0.0053      0.004     -1.199      0.231      -0.014       0.003
# C(HOUSEHOLD_SIZE_DESC)[T.4]     -0.0068      0.006     -1.152      0.250      -0.018       0.005
# C(HOUSEHOLD_SIZE_DESC)[T.5+]    -0.0048      0.005     -0.907      0.365      -0.015       0.006
# ==============================================================================
# Omnibus:                      158.344   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              415.200
# Skew:                           1.095   Prob(JB):                     6.93e-91
# Kurtosis:                       5.962   Cond. No.                         5.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     avg_spending_ratio_PURE_MEAT   R-squared:                       0.005
# Model:                                      OLS   Adj. R-squared:                 -0.001
# Method:                           Least Squares   F-statistic:                    0.8645
# Date:                          Sat, 14 Dec 2019   Prob (F-statistic):              0.485
# Time:                                  20:28:44   Log-Likelihood:                 897.27
# No. Observations:                           734   AIC:                            -1785.
# Df Residuals:                               729   BIC:                            -1762.
# Df Model:                                     4
# Covariance Type:                      nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.1840      0.005     39.201      0.000       0.175       0.193
# C(HOUSEHOLD_SIZE_DESC)[T.2]      0.0041      0.006      0.650      0.516      -0.008       0.016
# C(HOUSEHOLD_SIZE_DESC)[T.3]      0.0105      0.009      1.234      0.218      -0.006       0.027
# C(HOUSEHOLD_SIZE_DESC)[T.4]     -0.0098      0.011     -0.855      0.393      -0.032       0.013
# C(HOUSEHOLD_SIZE_DESC)[T.5+]    -0.0032      0.010     -0.309      0.757      -0.023       0.017
# ==============================================================================
# Omnibus:                       48.061   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.049
# Skew:                           0.618   Prob(JB):                     4.09e-13
# Kurtosis:                       3.579   Cond. No.                         5.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_RED_MEAT   R-squared:                       0.005
# Model:                                     OLS   Adj. R-squared:                 -0.001
# Method:                          Least Squares   F-statistic:                    0.9000
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):              0.463
# Time:                                 20:28:44   Log-Likelihood:                 1073.7
# No. Observations:                          734   AIC:                            -2137.
# Df Residuals:                              729   BIC:                            -2114.
# Df Model:                                    4
# Covariance Type:                     nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0995      0.004     26.957      0.000       0.092       0.107
# C(HOUSEHOLD_SIZE_DESC)[T.2]      0.0074      0.005      1.497      0.135      -0.002       0.017
# C(HOUSEHOLD_SIZE_DESC)[T.3]      0.0028      0.007      0.415      0.678      -0.010       0.016
# C(HOUSEHOLD_SIZE_DESC)[T.4]     -0.0024      0.009     -0.269      0.788      -0.020       0.015
# C(HOUSEHOLD_SIZE_DESC)[T.5+]    -0.0030      0.008     -0.376      0.707      -0.019       0.013
# ==============================================================================
# Omnibus:                       88.309   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.992
# Skew:                           0.880   Prob(JB):                     1.96e-27
# Kurtosis:                       3.961   Cond. No.                         5.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     avg_spending_ratio_WHITE_MEAT   R-squared:                       0.012
# Model:                                       OLS   Adj. R-squared:                  0.007
# Method:                            Least Squares   F-statistic:                     2.219
# Date:                           Sat, 14 Dec 2019   Prob (F-statistic):             0.0654
# Time:                                   20:28:44   Log-Likelihood:                 1628.0
# No. Observations:                            734   AIC:                            -3246.
# Df Residuals:                                729   BIC:                            -3223.
# Df Model:                                      4
# Covariance Type:                       nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0442      0.002     25.485      0.000       0.041       0.048
# C(HOUSEHOLD_SIZE_DESC)[T.2]     -0.0041      0.002     -1.745      0.081      -0.009       0.001
# C(HOUSEHOLD_SIZE_DESC)[T.3]      0.0042      0.003      1.323      0.186      -0.002       0.010
# C(HOUSEHOLD_SIZE_DESC)[T.4]     -0.0048      0.004     -1.143      0.254      -0.013       0.003
# C(HOUSEHOLD_SIZE_DESC)[T.5+]    -0.0017      0.004     -0.448      0.655      -0.009       0.006
# ==============================================================================
# Omnibus:                      160.700   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              326.578
# Skew:                           1.226   Prob(JB):                     1.21e-71
# Kurtosis:                       5.161   Cond. No.                         5.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_SEA_FOOD   R-squared:                       0.007
# Model:                                     OLS   Adj. R-squared:                  0.001
# Method:                          Least Squares   F-statistic:                     1.273
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):              0.279
# Time:                                 20:28:44   Log-Likelihood:                 1854.9
# No. Observations:                          734   AIC:                            -3700.
# Df Residuals:                              729   BIC:                            -3677.
# Df Model:                                    4
# Covariance Type:                     nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0187      0.001     14.698      0.000       0.016       0.021
# C(HOUSEHOLD_SIZE_DESC)[T.2]      0.0003      0.002      0.167      0.867      -0.003       0.004
# C(HOUSEHOLD_SIZE_DESC)[T.3]     -0.0004      0.002     -0.193      0.847      -0.005       0.004
# C(HOUSEHOLD_SIZE_DESC)[T.4]     -0.0058      0.003     -1.866      0.062      -0.012       0.000
# C(HOUSEHOLD_SIZE_DESC)[T.5+]    -0.0029      0.003     -1.056      0.291      -0.008       0.003
# ==============================================================================
# Omnibus:                      465.118   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4910.916
# Skew:                           2.751   Prob(JB):                         0.00
# Kurtosis:                      14.415   Cond. No.                         5.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### HH_COMP_DESC

# %%
results = ols('avg_spending_per_week ~ C(HH_COMP_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_MEAT ~ C(HH_COMP_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_VEGGIE ~ C(HH_COMP_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_PURE_MEAT ~ C(HH_COMP_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_RED_MEAT ~ C(HH_COMP_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_WHITE_MEAT ~ C(HH_COMP_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_SEA_FOOD ~ C(HH_COMP_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     avg_spending_per_week   R-squared:                       0.035
# Model:                               OLS   Adj. R-squared:                  0.028
# Method:                    Least Squares   F-statistic:                     5.243
# Date:                   Sat, 14 Dec 2019   Prob (F-statistic):           9.73e-05
# Time:                           20:29:00   Log-Likelihood:                -3387.9
# No. Observations:                    734   AIC:                             6788.
# Df Residuals:                        728   BIC:                             6815.
# Df Model:                              5
# Covariance Type:               nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              53.7130      3.660     14.676      0.000      46.528      60.898
# C(HH_COMP_DESC)[T.2 Adults Kids]        0.3413      4.113      0.083      0.934      -7.734       8.417
# C(HH_COMP_DESC)[T.2 Adults No Kids]    -5.5682      3.995     -1.394      0.164     -13.411       2.275
# C(HH_COMP_DESC)[T.Single Female]      -10.8246      4.246     -2.549      0.011     -19.161      -2.488
# C(HH_COMP_DESC)[T.Single Male]        -11.2245      4.526     -2.480      0.013     -20.111      -2.338
# C(HH_COMP_DESC)[T.Unknown]            -11.3076      4.718     -2.397      0.017     -20.570      -2.045
# ==============================================================================
# Omnibus:                      180.451   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              418.790
# Skew:                           1.302   Prob(JB):                     1.15e-91
# Kurtosis:                       5.628   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     avg_spending_ratio_MEAT   R-squared:                       0.015
# Model:                                 OLS   Adj. R-squared:                  0.008
# Method:                      Least Squares   F-statistic:                     2.201
# Date:                     Sat, 14 Dec 2019   Prob (F-statistic):             0.0525
# Time:                             20:29:00   Log-Likelihood:                 824.87
# No. Observations:                      734   AIC:                            -1638.
# Df Residuals:                          728   BIC:                            -1610.
# Df Model:                                5
# Covariance Type:                 nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.2674      0.012     22.716      0.000       0.244       0.291
# C(HH_COMP_DESC)[T.2 Adults Kids]       -0.0419      0.013     -3.164      0.002      -0.068      -0.016
# C(HH_COMP_DESC)[T.2 Adults No Kids]    -0.0333      0.013     -2.591      0.010      -0.059      -0.008
# C(HH_COMP_DESC)[T.Single Female]       -0.0388      0.014     -2.838      0.005      -0.066      -0.012
# C(HH_COMP_DESC)[T.Single Male]         -0.0387      0.015     -2.656      0.008      -0.067      -0.010
# C(HH_COMP_DESC)[T.Unknown]             -0.0296      0.015     -1.951      0.051      -0.059       0.000
# ==============================================================================
# Omnibus:                       39.633   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.099
# Skew:                           0.492   Prob(JB):                     8.02e-12
# Kurtosis:                       3.839   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     avg_spending_ratio_VEGGIE   R-squared:                       0.032
# Model:                                   OLS   Adj. R-squared:                  0.025
# Method:                        Least Squares   F-statistic:                     4.763
# Date:                       Sat, 14 Dec 2019   Prob (F-statistic):           0.000273
# Time:                               20:29:00   Log-Likelihood:                 1389.7
# No. Observations:                        734   AIC:                            -2767.
# Df Residuals:                            728   BIC:                            -2740.
# Df Model:                                  5
# Covariance Type:                   nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.0667      0.005     12.233      0.000       0.056       0.077
# C(HH_COMP_DESC)[T.2 Adults Kids]        0.0006      0.006      0.096      0.924      -0.011       0.013
# C(HH_COMP_DESC)[T.2 Adults No Kids]     0.0139      0.006      2.340      0.020       0.002       0.026
# C(HH_COMP_DESC)[T.Single Female]        0.0146      0.006      2.305      0.021       0.002       0.027
# C(HH_COMP_DESC)[T.Single Male]          0.0033      0.007      0.491      0.624      -0.010       0.017
# C(HH_COMP_DESC)[T.Unknown]              0.0004      0.007      0.053      0.957      -0.013       0.014
# ==============================================================================
# Omnibus:                      160.357   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              425.801
# Skew:                           1.104   Prob(JB):                     3.46e-93
# Kurtosis:                       6.008   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     avg_spending_ratio_PURE_MEAT   R-squared:                       0.007
# Model:                                      OLS   Adj. R-squared:                  0.001
# Method:                           Least Squares   F-statistic:                     1.093
# Date:                          Sat, 14 Dec 2019   Prob (F-statistic):              0.363
# Time:                                  20:29:00   Log-Likelihood:                 898.28
# No. Observations:                           734   AIC:                            -1785.
# Df Residuals:                               728   BIC:                            -1757.
# Df Model:                                     5
# Covariance Type:                      nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.2020      0.011     18.968      0.000       0.181       0.223
# C(HH_COMP_DESC)[T.2 Adults Kids]       -0.0195      0.012     -1.630      0.104      -0.043       0.004
# C(HH_COMP_DESC)[T.2 Adults No Kids]    -0.0122      0.012     -1.045      0.296      -0.035       0.011
# C(HH_COMP_DESC)[T.Single Female]       -0.0228      0.012     -1.846      0.065      -0.047       0.001
# C(HH_COMP_DESC)[T.Single Male]         -0.0211      0.013     -1.600      0.110      -0.047       0.005
# C(HH_COMP_DESC)[T.Unknown]             -0.0098      0.014     -0.716      0.474      -0.037       0.017
# ==============================================================================
# Omnibus:                       52.298   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.570
# Skew:                           0.643   Prob(JB):                     1.57e-14
# Kurtosis:                       3.652   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_RED_MEAT   R-squared:                       0.010
# Model:                                     OLS   Adj. R-squared:                  0.004
# Method:                          Least Squares   F-statistic:                     1.542
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):              0.175
# Time:                                 20:29:00   Log-Likelihood:                 1075.7
# No. Observations:                          734   AIC:                            -2139.
# Df Residuals:                              728   BIC:                            -2112.
# Df Model:                                    5
# Covariance Type:                     nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.1100      0.008     13.152      0.000       0.094       0.126
# C(HH_COMP_DESC)[T.2 Adults Kids]       -0.0126      0.009     -1.343      0.180      -0.031       0.006
# C(HH_COMP_DESC)[T.2 Adults No Kids]    -0.0013      0.009     -0.145      0.885      -0.019       0.017
# C(HH_COMP_DESC)[T.Single Female]       -0.0144      0.010     -1.481      0.139      -0.033       0.005
# C(HH_COMP_DESC)[T.Single Male]         -0.0113      0.010     -1.094      0.274      -0.032       0.009
# C(HH_COMP_DESC)[T.Unknown]             -0.0038      0.011     -0.355      0.722      -0.025       0.017
# ==============================================================================
# Omnibus:                       88.560   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              123.382
# Skew:                           0.882   Prob(JB):                     1.61e-27
# Kurtosis:                       3.960   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     avg_spending_ratio_WHITE_MEAT   R-squared:                       0.004
# Model:                                       OLS   Adj. R-squared:                 -0.003
# Method:                            Least Squares   F-statistic:                    0.5794
# Date:                           Sat, 14 Dec 2019   Prob (F-statistic):              0.716
# Time:                                   20:29:00   Log-Likelihood:                 1625.0
# No. Observations:                            734   AIC:                            -3238.
# Df Residuals:                                728   BIC:                            -3210.
# Df Model:                                      5
# Covariance Type:                       nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.0434      0.004     10.975      0.000       0.036       0.051
# C(HH_COMP_DESC)[T.2 Adults Kids]        0.0011      0.004      0.239      0.811      -0.008       0.010
# C(HH_COMP_DESC)[T.2 Adults No Kids]    -0.0027      0.004     -0.629      0.530      -0.011       0.006
# C(HH_COMP_DESC)[T.Single Female]       -0.0016      0.005     -0.355      0.723      -0.011       0.007
# C(HH_COMP_DESC)[T.Single Male]          0.0006      0.005      0.125      0.901      -0.009       0.010
# C(HH_COMP_DESC)[T.Unknown]              0.0013      0.005      0.256      0.798      -0.009       0.011
# ==============================================================================
# Omnibus:                      164.379   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              338.049
# Skew:                           1.247   Prob(JB):                     3.92e-74
# Kurtosis:                       5.199   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_SEA_FOOD   R-squared:                       0.006
# Model:                                     OLS   Adj. R-squared:                 -0.001
# Method:                          Least Squares   F-statistic:                    0.8257
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):              0.531
# Time:                                 20:29:00   Log-Likelihood:                 1854.5
# No. Observations:                          734   AIC:                            -3697.
# Df Residuals:                              728   BIC:                            -3669.
# Df Model:                                    5
# Covariance Type:                     nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.0176      0.003      6.086      0.000       0.012       0.023
# C(HH_COMP_DESC)[T.2 Adults Kids]       -0.0017      0.003     -0.533      0.594      -0.008       0.005
# C(HH_COMP_DESC)[T.2 Adults No Kids]     0.0016      0.003      0.503      0.615      -0.005       0.008
# C(HH_COMP_DESC)[T.Single Female]        0.0022      0.003      0.653      0.514      -0.004       0.009
# C(HH_COMP_DESC)[T.Single Male]         -0.0002      0.004     -0.051      0.960      -0.007       0.007
# C(HH_COMP_DESC)[T.Unknown]              0.0006      0.004      0.168      0.866      -0.007       0.008
# ==============================================================================
# Omnibus:                      468.841   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5052.865
# Skew:                           2.773   Prob(JB):                         0.00
# Kurtosis:                      14.596   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### KID_CATEGORY_DESC

# %%
results = ols('avg_spending_per_week ~ C(KID_CATEGORY_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_MEAT ~ C(KID_CATEGORY_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_VEGGIE ~ C(KID_CATEGORY_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_PURE_MEAT ~ C(KID_CATEGORY_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_RED_MEAT ~ C(KID_CATEGORY_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_WHITE_MEAT ~ C(KID_CATEGORY_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_SEA_FOOD ~ C(KID_CATEGORY_DESC)', data = df_spent_and_demog).fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     avg_spending_per_week   R-squared:                       0.032
# Model:                               OLS   Adj. R-squared:                  0.028
# Method:                    Least Squares   F-statistic:                     7.918
# Date:                   Sat, 14 Dec 2019   Prob (F-statistic):           3.34e-05
# Time:                           20:29:32   Log-Likelihood:                -3389.1
# No. Observations:                    734   AIC:                             6786.
# Df Residuals:                        730   BIC:                             6805.
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     45.1025      1.089     41.433      0.000      42.965      47.240
# C(KID_CATEGORY_DESC)[T.1]      4.9416      2.622      1.885      0.060      -0.206      10.089
# C(KID_CATEGORY_DESC)[T.2]     12.3132      3.515      3.503      0.000       5.413      19.214
# C(KID_CATEGORY_DESC)[T.3+]    11.5550      3.235      3.572      0.000       5.204      17.906
# ==============================================================================
# Omnibus:                      177.744   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              403.629
# Skew:                           1.294   Prob(JB):                     2.26e-88
# Kurtosis:                       5.550   Cond. No.                         4.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     avg_spending_ratio_MEAT   R-squared:                       0.003
# Model:                                 OLS   Adj. R-squared:                 -0.001
# Method:                      Least Squares   F-statistic:                    0.7259
# Date:                     Sat, 14 Dec 2019   Prob (F-statistic):              0.537
# Time:                             20:29:32   Log-Likelihood:                 820.46
# No. Observations:                      734   AIC:                            -1633.
# Df Residuals:                          730   BIC:                            -1615.
# Df Model:                                3
# Covariance Type:                 nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.2322      0.004     66.035      0.000       0.225       0.239
# C(KID_CATEGORY_DESC)[T.1]      0.0098      0.008      1.156      0.248      -0.007       0.026
# C(KID_CATEGORY_DESC)[T.2]     -0.0004      0.011     -0.034      0.973      -0.023       0.022
# C(KID_CATEGORY_DESC)[T.3+]    -0.0077      0.010     -0.740      0.459      -0.028       0.013
# ==============================================================================
# Omnibus:                       41.367   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.642
# Skew:                           0.491   Prob(JB):                     8.27e-13
# Kurtosis:                       3.925   Cond. No.                         4.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     avg_spending_ratio_VEGGIE   R-squared:                       0.015
# Model:                                   OLS   Adj. R-squared:                  0.011
# Method:                        Least Squares   F-statistic:                     3.714
# Date:                       Sat, 14 Dec 2019   Prob (F-statistic):             0.0114
# Time:                               20:29:32   Log-Likelihood:                 1383.5
# No. Observations:                        734   AIC:                            -2759.
# Df Residuals:                            730   BIC:                            -2741.
# Df Model:                                  3
# Covariance Type:                   nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.0773      0.002     47.335      0.000       0.074       0.081
# C(KID_CATEGORY_DESC)[T.1]     -0.0099      0.004     -2.526      0.012      -0.018      -0.002
# C(KID_CATEGORY_DESC)[T.2]     -0.0111      0.005     -2.096      0.036      -0.021      -0.001
# C(KID_CATEGORY_DESC)[T.3+]    -0.0085      0.005     -1.746      0.081      -0.018       0.001
# ==============================================================================
# Omnibus:                      153.296   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              382.435
# Skew:                           1.080   Prob(JB):                     9.02e-84
# Kurtosis:                       5.799   Cond. No.                         4.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     avg_spending_ratio_PURE_MEAT   R-squared:                       0.001
# Model:                                      OLS   Adj. R-squared:                 -0.003
# Method:                           Least Squares   F-statistic:                    0.3102
# Date:                          Sat, 14 Dec 2019   Prob (F-statistic):              0.818
# Time:                                  20:29:32   Log-Likelihood:                 896.00
# No. Observations:                           734   AIC:                            -1784.
# Df Residuals:                               730   BIC:                            -1766.
# Df Model:                                     3
# Covariance Type:                      nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.1860      0.003     58.629      0.000       0.180       0.192
# C(KID_CATEGORY_DESC)[T.1]      0.0055      0.008      0.717      0.473      -0.010       0.020
# C(KID_CATEGORY_DESC)[T.2]     -0.0032      0.010     -0.308      0.758      -0.023       0.017
# C(KID_CATEGORY_DESC)[T.3+]    -0.0041      0.009     -0.431      0.666      -0.023       0.014
# ==============================================================================
# Omnibus:                       49.815   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.596
# Skew:                           0.630   Prob(JB):                     1.15e-13
# Kurtosis:                       3.599   Cond. No.                         4.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_RED_MEAT   R-squared:                       0.001
# Model:                                     OLS   Adj. R-squared:                 -0.003
# Method:                          Least Squares   F-statistic:                    0.2932
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):              0.830
# Time:                                 20:29:32   Log-Likelihood:                 1072.3
# No. Observations:                          734   AIC:                            -2137.
# Df Residuals:                              730   BIC:                            -2118.
# Df Model:                                    3
# Covariance Type:                     nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.1033      0.002     41.405      0.000       0.098       0.108
# C(KID_CATEGORY_DESC)[T.1]     -0.0004      0.006     -0.061      0.952      -0.012       0.011
# C(KID_CATEGORY_DESC)[T.2]     -0.0036      0.008     -0.445      0.656      -0.019       0.012
# C(KID_CATEGORY_DESC)[T.3+]    -0.0064      0.007     -0.861      0.390      -0.021       0.008
# ==============================================================================
# Omnibus:                       89.090   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.640
# Skew:                           0.884   Prob(JB):                     8.61e-28
# Kurtosis:                       3.976   Cond. No.                         4.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     avg_spending_ratio_WHITE_MEAT   R-squared:                       0.002
# Model:                                       OLS   Adj. R-squared:                 -0.002
# Method:                            Least Squares   F-statistic:                    0.5271
# Date:                           Sat, 14 Dec 2019   Prob (F-statistic):              0.664
# Time:                                   20:29:32   Log-Likelihood:                 1624.3
# No. Observations:                            734   AIC:                            -3241.
# Df Residuals:                                730   BIC:                            -3222.
# Df Model:                                      3
# Covariance Type:                       nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.0421      0.001     35.756      0.000       0.040       0.044
# C(KID_CATEGORY_DESC)[T.1]      0.0035      0.003      1.241      0.215      -0.002       0.009
# C(KID_CATEGORY_DESC)[T.2]      0.0014      0.004      0.362      0.718      -0.006       0.009
# C(KID_CATEGORY_DESC)[T.3+]     0.0006      0.003      0.173      0.863      -0.006       0.007
# ==============================================================================
# Omnibus:                      170.806   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              364.767
# Skew:                           1.274   Prob(JB):                     6.19e-80
# Kurtosis:                       5.330   Cond. No.                         4.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_SEA_FOOD   R-squared:                       0.007
# Model:                                     OLS   Adj. R-squared:                  0.003
# Method:                          Least Squares   F-statistic:                     1.696
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):              0.166
# Time:                                 20:29:32   Log-Likelihood:                 1854.9
# No. Observations:                          734   AIC:                            -3702.
# Df Residuals:                              730   BIC:                            -3683.
# Df Model:                                    3
# Covariance Type:                     nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.0190      0.001     22.119      0.000       0.017       0.021
# C(KID_CATEGORY_DESC)[T.1]     -0.0011      0.002     -0.545      0.586      -0.005       0.003
# C(KID_CATEGORY_DESC)[T.2]     -0.0055      0.003     -1.990      0.047      -0.011   -7.31e-05
# C(KID_CATEGORY_DESC)[T.3+]    -0.0032      0.003     -1.253      0.211      -0.008       0.002
# ==============================================================================
# Omnibus:                      465.393   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4927.086
# Skew:                           2.752   Prob(JB):                         0.00
# Kurtosis:                      14.437   Cond. No.                         4.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### MARITAL_STATUS_CODE

# %%
results = ols('avg_spending_per_week ~ C(MARITAL_STATUS_CODE)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_MEAT ~ C(MARITAL_STATUS_CODE)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_VEGGIE ~ C(MARITAL_STATUS_CODE)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_PURE_MEAT ~ C(MARITAL_STATUS_CODE)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_RED_MEAT ~ C(MARITAL_STATUS_CODE)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_WHITE_MEAT ~ C(MARITAL_STATUS_CODE)', data = df_spent_and_demog).fit()
print(results.summary())
results = ols('avg_spending_ratio_SEA_FOOD ~ C(MARITAL_STATUS_CODE)', data = df_spent_and_demog).fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     avg_spending_per_week   R-squared:                       0.017
# Model:                               OLS   Adj. R-squared:                  0.014
# Method:                    Least Squares   F-statistic:                     6.287
# Date:                   Sat, 14 Dec 2019   Prob (F-statistic):            0.00196
# Time:                           20:32:11   Log-Likelihood:                -3394.6
# No. Observations:                    734   AIC:                             6795.
# Df Residuals:                        731   BIC:                             6809.
# Df Model:                              2
# Covariance Type:               nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      51.5301      1.404     36.692      0.000      48.773      54.287
# C(MARITAL_STATUS_CODE)[T.B]    -6.6189      2.782     -2.379      0.018     -12.081      -1.157
# C(MARITAL_STATUS_CODE)[T.U]    -6.5299      1.974     -3.309      0.001     -10.404      -2.655
# ==============================================================================
# Omnibus:                      189.942   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              464.988
# Skew:                           1.345   Prob(JB):                    1.07e-101
# Kurtosis:                       5.823   Cond. No.                         3.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     avg_spending_ratio_MEAT   R-squared:                       0.005
# Model:                                 OLS   Adj. R-squared:                  0.002
# Method:                      Least Squares   F-statistic:                     1.908
# Date:                     Sat, 14 Dec 2019   Prob (F-statistic):              0.149
# Time:                             20:32:11   Log-Likelihood:                 821.27
# No. Observations:                      734   AIC:                            -1637.
# Df Residuals:                          731   BIC:                            -1623.
# Df Model:                                2
# Covariance Type:                 nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.2292      0.004     50.963      0.000       0.220       0.238
# C(MARITAL_STATUS_CODE)[T.B]    -0.0045      0.009     -0.502      0.616      -0.022       0.013
# C(MARITAL_STATUS_CODE)[T.U]     0.0100      0.006      1.582      0.114      -0.002       0.022
# ==============================================================================
# Omnibus:                       43.251   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.154
# Skew:                           0.495   Prob(JB):                     8.66e-14
# Kurtosis:                       3.993   Cond. No.                         3.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     avg_spending_ratio_VEGGIE   R-squared:                       0.006
# Model:                                   OLS   Adj. R-squared:                  0.003
# Method:                        Least Squares   F-statistic:                     2.046
# Date:                       Sat, 14 Dec 2019   Prob (F-statistic):              0.130
# Time:                               20:32:11   Log-Likelihood:                 1380.0
# No. Observations:                        734   AIC:                            -2754.
# Df Residuals:                            731   BIC:                            -2740.
# Df Model:                                  2
# Covariance Type:                   nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0773      0.002     36.789      0.000       0.073       0.081
# C(MARITAL_STATUS_CODE)[T.B]    -0.0028      0.004     -0.682      0.495      -0.011       0.005
# C(MARITAL_STATUS_CODE)[T.U]    -0.0060      0.003     -2.022      0.044      -0.012      -0.000
# ==============================================================================
# Omnibus:                      164.867   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              423.256
# Skew:                           1.148   Prob(JB):                     1.23e-92
# Kurtosis:                       5.927   Cond. No.                         3.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     avg_spending_ratio_PURE_MEAT   R-squared:                       0.004
# Model:                                      OLS   Adj. R-squared:                  0.001
# Method:                           Least Squares   F-statistic:                     1.456
# Date:                          Sat, 14 Dec 2019   Prob (F-statistic):              0.234
# Time:                                  20:32:11   Log-Likelihood:                 896.99
# No. Observations:                           734   AIC:                            -1788.
# Df Residuals:                               731   BIC:                            -1774.
# Df Model:                                     2
# Covariance Type:                      nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1856      0.004     45.750      0.000       0.178       0.194
# C(MARITAL_STATUS_CODE)[T.B]    -0.0092      0.008     -1.139      0.255      -0.025       0.007
# C(MARITAL_STATUS_CODE)[T.U]     0.0044      0.006      0.777      0.438      -0.007       0.016
# ==============================================================================
# Omnibus:                       48.222   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.273
# Skew:                           0.620   Prob(JB):                     3.66e-13
# Kurtosis:                       3.580   Cond. No.                         3.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_RED_MEAT   R-squared:                       0.001
# Model:                                     OLS   Adj. R-squared:                 -0.001
# Method:                          Least Squares   F-statistic:                    0.5259
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):              0.591
# Time:                                 20:32:11   Log-Likelihood:                 1072.4
# No. Observations:                          734   AIC:                            -2139.
# Df Residuals:                              731   BIC:                            -2125.
# Df Model:                                    2
# Covariance Type:                     nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1036      0.003     32.424      0.000       0.097       0.110
# C(MARITAL_STATUS_CODE)[T.B]    -0.0063      0.006     -0.995      0.320      -0.019       0.006
# C(MARITAL_STATUS_CODE)[T.U]    -0.0006      0.004     -0.125      0.900      -0.009       0.008
# ==============================================================================
# Omnibus:                       88.090   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.418
# Skew:                           0.880   Prob(JB):                     2.61e-27
# Kurtosis:                       3.951   Cond. No.                         3.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     avg_spending_ratio_WHITE_MEAT   R-squared:                       0.004
# Model:                                       OLS   Adj. R-squared:                  0.002
# Method:                            Least Squares   F-statistic:                     1.619
# Date:                           Sat, 14 Dec 2019   Prob (F-statistic):              0.199
# Time:                                   20:32:11   Log-Likelihood:                 1625.2
# No. Observations:                            734   AIC:                            -3244.
# Df Residuals:                                731   BIC:                            -3231.
# Df Model:                                      2
# Covariance Type:                       nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0414      0.002     27.515      0.000       0.038       0.044
# C(MARITAL_STATUS_CODE)[T.B]    -0.0008      0.003     -0.261      0.794      -0.007       0.005
# C(MARITAL_STATUS_CODE)[T.U]     0.0033      0.002      1.568      0.117      -0.001       0.007
# ==============================================================================
# Omnibus:                      163.345   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              331.103
# Skew:                           1.247   Prob(JB):                     1.26e-72
# Kurtosis:                       5.146   Cond. No.                         3.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     avg_spending_ratio_SEA_FOOD   R-squared:                       0.001
# Model:                                     OLS   Adj. R-squared:                 -0.002
# Method:                          Least Squares   F-statistic:                    0.3064
# Date:                         Sat, 14 Dec 2019   Prob (F-statistic):              0.736
# Time:                                 20:32:11   Log-Likelihood:                 1852.7
# No. Observations:                          734   AIC:                            -3699.
# Df Residuals:                              731   BIC:                            -3686.
# Df Model:                                    2
# Covariance Type:                     nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0183      0.001     16.558      0.000       0.016       0.020
# C(MARITAL_STATUS_CODE)[T.B]    -0.0015      0.002     -0.671      0.502      -0.006       0.003
# C(MARITAL_STATUS_CODE)[T.U]     0.0002      0.002      0.135      0.893      -0.003       0.003
# ==============================================================================
# Omnibus:                      465.395   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4875.745
# Skew:                           2.757   Prob(JB):                         0.00
# Kurtosis:                      14.358   Cond. No.                         3.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
